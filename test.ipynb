# %%
import itertools

import pulp
from pulp import LpProblem, LpVariable, LpBinary, lpSum

n_weeks = 2
days_per_week = 7
total_days = n_weeks * days_per_week
shop_open = 10  # 10 AM
shop_close = 20  # 8 PM
min_working_hours = 5
max_working_hours = 9
n_employees = 25

### DATA

# 5-day or 4-day contract type (60% each for now)
five_days_count = n_employees * 0.6

brands = {
    "PHONE": ["PHONE1", "PHONE2"],
    "TV": ["TV1", "TV2", "TV3"]
}
brand_items = tuple(itertools.chain(*brands.values()))

# employee table  e# : ( 4/5 day , [brand_item, ...] )
employees = {f'e{i}': (5*n_weeks if i < five_days_count else 4*n_weeks, [brand_items[i % len(brand_items)]]) for i in range(n_employees)}
# print(employees)

staffing_requirements = {
    "PHONE1": 1,
    "PHONE2": 1,
    "TV1": 1,
    "TV2": 1,
    "TV3": 1}

# the hours on which it is possible to commence a 5-hr shift
poss_starts = [hr for hr in range(shop_open, shop_close - min_working_hours + 1)]

prob = LpProblem('shift_sked')

### SETS / INDEXES

hours = list(range(shop_open, shop_close))  # convenience for readability...
days = list(range(total_days))
#                                                     Domain trim-down:  vvvv                 vvvv
EDHB_employees = {(e, d, h, b) for e in employees for d in days for h in poss_starts for b in employees[e][1]}
EDHB_brand_items = {(e, d, h, b) for e in employees for d in days for h in hours for b in employees[e][1]}

### VARS

start_shift = LpVariable.dicts('start', indices=EDHB_employees, cat=LpBinary) # e starts shift on day d, hour h, for brand item b
covers = LpVariable.dicts('covers', indices=EDHB_brand_items, cat=LpBinary)  # e covers brand item b on day d, hour h
max_shifts = LpVariable('max_shifts')  # the max shifts by any employee

### OBJ:  Minimize shift starts
prob += lpSum(start_shift)

# alternate objectives for experimenting...
# prob += lpSum(covers)  # should produce days*hours*requirements
# prob += max_shifts  # the max number of shifts by any employee  NOTE:  This is tougher solve, longer...

### CONSTRAINTS

# 1 & 2.  Limit shift starts by 4/5 day limit, and can only start 1 shift/day
for e in employees:
    prob += sum(start_shift[e, d, h, b] for d in days for h in poss_starts for b in employees[e][1]) <= employees[e][0]
    for d in days:
        prob += sum(start_shift[e, d, h, b] for h in poss_starts for b in employees[e][1]) <= 1

# 3. Link coverage to shift starting
for (e, d, h, b) in EDHB_brand_items:
    if b not in employees[e][1]:  # this employee cannot 'cover' this item
        prob += covers[e, d, h, b] <= 0
    elif h in poss_starts:  # a start or continued coverage can work...
        prev_hour = covers[e, d, h-1, b] if h > shop_open else None
        prob += covers[e, d, h, b] <= start_shift[e, d, h, b] + prev_hour
    else:  # only previous hour coverage can work (start not possible)
        prob += covers[e, d, h, b] <= covers[e, d, h-1, b]

# 4.  min/max coverage
for e in employees:
    for d in days:
        starts_shift = sum(start_shift[e, d, h, b] for h in poss_starts for b in employees[e][1])
        prob += sum(covers[e, d, h, b] for h in hours for b in employees[e][1]) <= max_working_hours * starts_shift
        prob += sum(covers[e, d, h, b] for h in hours for b in employees[e][1]) >= min_working_hours * starts_shift

# 5.  brand-item coverage minimums
for (d, h, b) in itertools.product(days, hours, brand_items):
    prob += sum(covers[e, d, h, b] for e in employees if b in employees[e][1]) >= staffing_requirements[b]

# 6.  Capture max shifts
for e in employees:
    prob += max_shifts >= sum(start_shift[e, d, h, b] for d in days for h in poss_starts for b in employees[e][1])

# print(prob)

#cbc_path = '/opt/homebrew/opt/cbc/bin/cbc'
#solver = pulp.COIN_CMD(path=cbc_path)
res = prob.solve()

# highs_path = '/opt/homebrew/bin/highs'
# solver_2 = pulp.HiGHS_CMD(path=highs_path)
# res = prob.solve(solver_2)
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yukaisun/opt/anaconda3/lib/python3.8/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/s1/w69x8mm13wz_1npk05p7rzy00000gn/T/359b8e603e7c4b01aa30018ad14e4c57-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/s1/w69x8mm13wz_1npk05p7rzy00000gn/T/359b8e603e7c4b01aa30018ad14e4c57-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5305 COLUMNS
# At line 48381 RHS
# At line 53682 BOUNDS
# At line 59284 ENDATA
# Problem MODEL has 5300 rows, 5601 columns and 29775 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 77.7778 - 0.48 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 41 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 12 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 2 strengthened rows, 0 substitutions
# Cgl0004I processed model has 5275 rows, 5600 columns (5600 integer (5600 of which binary)) and 27650 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 1479 integers unsatisfied sum - 148.647
# Cbc0038I Pass   1: (1.02 seconds) suminf.  147.77778 (1488) obj. 77.7778 iterations 1647
# Cbc0038I Pass   2: (1.03 seconds) suminf.  147.80119 (1466) obj. 78.8012 iterations 115
# Cbc0038I Pass   3: (1.05 seconds) suminf.  147.66667 (1480) obj. 78.6667 iterations 83
# Cbc0038I Pass   4: (1.07 seconds) suminf.  144.58333 (1444) obj. 79.5833 iterations 78
# Cbc0038I Pass   5: (1.08 seconds) suminf.  144.55556 (1451) obj. 79.5556 iterations 39
# Cbc0038I Pass   6: (1.10 seconds) suminf.  143.21389 (1412) obj. 80.7694 iterations 128
# Cbc0038I Pass   7: (1.12 seconds) suminf.  142.77778 (1440) obj. 80.4444 iterations 78
# Cbc0038I Pass   8: (1.13 seconds) suminf.  142.55556 (1424) obj. 81.4444 iterations 70
# Cbc0038I Pass   9: (1.15 seconds) suminf.  142.33333 (1424) obj. 81.3333 iterations 36
# Cbc0038I Pass  10: (1.16 seconds) suminf.  140.61111 (1397) obj. 82.3889 iterations 72
# Cbc0038I Pass  11: (1.18 seconds) suminf.  140.33333 (1406) obj. 82.2222 iterations 49
# Cbc0038I Pass  12: (1.19 seconds) suminf.  138.44444 (1394) obj. 82.3333 iterations 46
# Cbc0038I Pass  13: (1.20 seconds) suminf.  138.22222 (1396) obj. 82.2222 iterations 36
# Cbc0038I Pass  14: (1.22 seconds) suminf.  133.31111 (1332) obj. 84.2 iterations 85
# Cbc0038I Pass  15: (1.23 seconds) suminf.  133.00000 (1343) obj. 84 iterations 53
# Cbc0038I Pass  16: (1.25 seconds) suminf.  132.11111 (1327) obj. 85 iterations 46
# Cbc0038I Pass  17: (1.27 seconds) suminf.  131.88889 (1323) obj. 84.8889 iterations 30
# Cbc0038I Pass  18: (1.28 seconds) suminf.  130.88889 (1321) obj. 84.8889 iterations 6
# Cbc0038I Pass  19: (1.30 seconds) suminf.  131.73841 (1333) obj. 85.0984 iterations 102
# Cbc0038I Pass  20: (1.37 seconds) suminf.  142.38254 (932) obj. 95.6999 iterations 1412
# Cbc0038I Pass  21: (1.46 seconds) suminf.  125.82222 (1242) obj. 90.2222 iterations 1551
# Cbc0038I Pass  22: (1.47 seconds) suminf.  122.02222 (1229) obj. 90.2222 iterations 35
# Cbc0038I Pass  23: (1.48 seconds) suminf.  122.02222 (1229) obj. 90.2222 iterations 11
# Cbc0038I Pass  24: (1.50 seconds) suminf.  121.03111 (1213) obj. 91.5333 iterations 131
# Cbc0038I Pass  25: (1.51 seconds) suminf.  119.51111 (1208) obj. 91.1111 iterations 89
# Cbc0038I Pass  26: (1.53 seconds) suminf.  119.01389 (1168) obj. 93.9028 iterations 157
# Cbc0038I Pass  27: (1.54 seconds) suminf.  116.62222 (1170) obj. 93.7778 iterations 97
# Cbc0038I Pass  28: (1.56 seconds) suminf.  114.48889 (1134) obj. 95.6444 iterations 118
# Cbc0038I Pass  29: (1.58 seconds) suminf.  114.40000 (1143) obj. 95.5556 iterations 62
# Cbc0038I Pass  30: (1.59 seconds) suminf.  110.66389 (1116) obj. 96.4444 iterations 39
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 3322 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 5275 rows 5600 columns, reduced to 3110 rows 2278 columns - too large
# Cbc0038I Mini branch and bound did not improve solution (1.66 seconds)
# Cbc0038I After 1.66 seconds - Feasibility pump exiting - took 0.64 seconds
# Cbc0031I 285 added rows had average density of 42.936842
# Cbc0013I At root node, 285 cuts changed objective from 77.777778 to 139.5999 in 36 passes
# Cbc0014I Cut generator 0 (Probing) - 237 row cuts average 17.0 elements, 0 column cuts (166 active)  in 0.472 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 5309 row cuts average 86.5 elements, 0 column cuts (0 active)  in 2.530 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 69 row cuts average 26.5 elements, 0 column cuts (0 active)  in 1.022 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.069 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 488 row cuts average 59.4 elements, 0 column cuts (0 active)  in 0.374 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.027 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 2561 row cuts average 60.9 elements, 0 column cuts (0 active)  in 2.461 seconds - new frequency is 1
# Cbc0014I Cut generator 7 (ZeroHalf) - 1502 row cuts average 15.0 elements, 0 column cuts (0 active)  in 5.397 seconds - new frequency is 1
# Cbc0010I After 0 nodes, 1 on tree, 1e+50 best solution, best possible 139.5999 (23.61 seconds)
# Cbc0004I Integer solution of 142 found after 23604 iterations and 81 nodes (37.57 seconds)
# Cbc0038I Full problem 5275 rows 5600 columns, reduced to 220 rows 156 columns
# Cbc0038I Full problem 5275 rows 5600 columns, reduced to 137 rows 105 columns
# Cbc0010I After 100 nodes, 64 on tree, 142 best solution, best possible 139.5999 (39.40 seconds)
# Cbc0012I Integer solution of 141 found by rounding after 23829 iterations and 103 nodes (39.60 seconds)
# Cbc0004I Integer solution of 140 found after 24957 iterations and 187 nodes (51.21 seconds)
# Cbc0001I Search completed - best objective 140, took 24957 iterations and 187 nodes (51.22 seconds)
# Cbc0032I Strong branching done 1376 times (9337 iterations), fathomed 0 nodes and fixed 11 variables
# Cbc0035I Maximum depth 68, 537 variables fixed on reduced cost
# Cuts at root node changed objective from 77.7778 to 139.6
# Probing was tried 36 times and created 237 cuts of which 166 were active after adding rounds of cuts (0.472 seconds)
# Gomory was tried 229 times and created 5370 cuts of which 0 were active after adding rounds of cuts (3.302 seconds)
# Knapsack was tried 36 times and created 69 cuts of which 0 were active after adding rounds of cuts (1.022 seconds)
# Clique was tried 36 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.069 seconds)
# MixedIntegerRounding2 was tried 229 times and created 552 cuts of which 0 were active after adding rounds of cuts (1.434 seconds)
# FlowCover was tried 36 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.027 seconds)
# TwoMirCuts was tried 229 times and created 2605 cuts of which 0 were active after adding rounds of cuts (3.487 seconds)
# ZeroHalf was tried 229 times and created 1699 cuts of which 0 were active after adding rounds of cuts (16.166 seconds)
# ImplicationCuts was tried 21 times and created 7 cuts of which 0 were active after adding rounds of cuts (0.013 seconds)
#
# Result - Optimal solution found
#
# Objective value:                140.00000000
# Enumerated nodes:               187
# Total iterations:               24957
# Time (CPU seconds):             40.42
# Time (Wallclock seconds):       51.47
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       40.46   (Wallclock seconds):       51.56
